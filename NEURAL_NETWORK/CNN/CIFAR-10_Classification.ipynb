# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
from tensorflow.keras import datasets
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# %%
from tensorflow.keras.utils import to_categorical

# Normalize the images to values between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# DNN MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.losses import SparseCategoricalCrossentropy

model = Sequential()

model.add(Input(shape=(32, 32, 3)))
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))

model.add(Dense(10, activation='linear'))

model.compile(optimizer='adam', loss=BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=128, validation_data=(X_test, y_test))

y_pred_probs = model.predict(X_test)
y_pred_probs = tf.nn.softmax(y_pred_probs)

y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_pred_one_hot = to_categorical(y_pred_labels, num_classes=10)
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.2705 - loss: 0.3131 - val_accuracy: 0.3657 - val_loss: 0.2674
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.3937 - loss: 0.2593 - val_accuracy: 0.4136 - val_loss: 0.2519
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.4308 - loss: 0.2465 - val_accuracy: 0.4360 - val_loss: 0.2435
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.4503 - loss: 0.2379 - val_accuracy: 0.4329 - val_loss: 0.2424
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.4662 - loss: 0.2315 - val_accuracy: 0.4616 - val_loss: 0.2338
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.4833 - loss: 0.2254 - val_accuracy: 0.4761 - val_loss: 0.2305
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.4933 - loss: 0.2221 - val_accuracy: 0.4775 - val_loss: 0.2278
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5024 - loss: 0.2190 - val_accuracy: 0.4801 - val_loss: 0.2262
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5168 - loss: 0.2135 - val_accuracy: 0.4811 - val_loss: 0.2255
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5259 - loss: 0.2101 - val_accuracy: 0.5002 - val_loss: 0.2173
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.5347 - loss: 0.2068 - val_accuracy: 0.4948 - val_loss: 0.2206
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5365 - loss: 0.2052 - val_accuracy: 0.5013 - val_loss: 0.2184
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5514 - loss: 0.2006 - val_accuracy: 0.5110 - val_loss: 0.2166
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.5582 - loss: 0.1984 - val_accuracy: 0.5150 - val_loss: 0.2140
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.5647 - loss: 0.1956 - val_accuracy: 0.5080 - val_loss: 0.2178
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5771 - loss: 0.1917 - val_accuracy: 0.5174 - val_loss: 0.2141
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.5763 - loss: 0.1908 - val_accuracy: 0.5131 - val_loss: 0.2165
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5838 - loss: 0.1887 - val_accuracy: 0.5156 - val_loss: 0.2159
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.5903 - loss: 0.1859 - val_accuracy: 0.5261 - val_loss: 0.2138
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5998 - loss: 0.1837 - val_accuracy: 0.5274 - val_loss: 0.2113
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6046 - loss: 0.1819 - val_accuracy: 0.5289 - val_loss: 0.2123
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6112 - loss: 0.1785 - val_accuracy: 0.5176 - val_loss: 0.2198
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6121 - loss: 0.1779 - val_accuracy: 0.5266 - val_loss: 0.2142
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6239 - loss: 0.1738 - val_accuracy: 0.5261 - val_loss: 0.2145
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6277 - loss: 0.1731 - val_accuracy: 0.5317 - val_loss: 0.2135
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6309 - loss: 0.1713 - val_accuracy: 0.5342 - val_loss: 0.2148
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6388 - loss: 0.1687 - val_accuracy: 0.5291 - val_loss: 0.2182
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6407 - loss: 0.1675 - val_accuracy: 0.5260 - val_loss: 0.2178
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6457 - loss: 0.1652 - val_accuracy: 0.5283 - val_loss: 0.2200
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6559 - loss: 0.1631 - val_accuracy: 0.5185 - val_loss: 0.2250
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6576 - loss: 0.1607 - val_accuracy: 0.5319 - val_loss: 0.2179
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6665 - loss: 0.1579 - val_accuracy: 0.5157 - val_loss: 0.2304
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6604 - loss: 0.1599 - val_accuracy: 0.5212 - val_loss: 0.2248
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6662 - loss: 0.1583 - val_accuracy: 0.5312 - val_loss: 0.2257
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6771 - loss: 0.1539 - val_accuracy: 0.5257 - val_loss: 0.2243
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6806 - loss: 0.1516 - val_accuracy: 0.5263 - val_loss: 0.2270
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6787 - loss: 0.1527 - val_accuracy: 0.5147 - val_loss: 0.2381
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6851 - loss: 0.1514 - val_accuracy: 0.5235 - val_loss: 0.2357
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6954 - loss: 0.1471 - val_accuracy: 0.5238 - val_loss: 0.2317
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6993 - loss: 0.1460 - val_accuracy: 0.5269 - val_loss: 0.2357
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6989 - loss: 0.1449 - val_accuracy: 0.5253 - val_loss: 0.2373
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7026 - loss: 0.1430 - val_accuracy: 0.5307 - val_loss: 0.2344
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7061 - loss: 0.1419 - val_accuracy: 0.5247 - val_loss: 0.2426
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7158 - loss: 0.1399 - val_accuracy: 0.5244 - val_loss: 0.2404
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7172 - loss: 0.1387 - val_accuracy: 0.5210 - val_loss: 0.2452
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7172 - loss: 0.1377 - val_accuracy: 0.5245 - val_loss: 0.2416
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7226 - loss: 0.1366 - val_accuracy: 0.5329 - val_loss: 0.2431
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7245 - loss: 0.1355 - val_accuracy: 0.5172 - val_loss: 0.2535
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7279 - loss: 0.1339 - val_accuracy: 0.5244 - val_loss: 0.2511
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7338 - loss: 0.1324 - val_accuracy: 0.5152 - val_loss: 0.2530
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, f1_score

accuracy = accuracy_score(y_test, y_pred_one_hot)
print(f'Accuracy: {accuracy}')

f1_macro = f1_score(y_test, y_pred_one_hot, average='macro')
f1_micro = f1_score(y_test, y_pred_one_hot, average='micro')
f1_weighted = f1_score(y_test, y_pred_one_hot, average='weighted')
f1_samples = f1_score(y_test, y_pred_one_hot, average='samples')

print(f'F1 Macro: {f1_macro}')
print(f'F1 Micro: {f1_micro}')
print(f'F1 Weighted: {f1_weighted}')
print(f'F1 Samples: {f1_samples}')
# Out:
# Accuracy: 0.5152
# F1 Macro: 0.5124141825496565
# F1 Micro: 0.5152
# F1 Weighted: 0.5124141825496564
# F1 Samples: 0.5152

# %% [markdown]
# CNN MODEL

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# %%
X_train = X_train.reshape(-1, 32, 32, 3).astype('float32') / 255.0
X_test = X_test.reshape(-1, 32, 32, 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='linear'))

model.compile(optimizer='adam', loss=BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=128, validation_data=(X_test, y_test))

y_pred_probs = model.predict(X_test)
y_pred_probs = tf.nn.softmax(y_pred_probs)

y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_pred_one_hot = to_categorical(y_pred_labels, num_classes=10)
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.2948 - loss: 0.3035 - val_accuracy: 0.4940 - val_loss: 0.2259
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5286 - loss: 0.2127 - val_accuracy: 0.5552 - val_loss: 0.2020
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.5924 - loss: 0.1889 - val_accuracy: 0.6120 - val_loss: 0.1786
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.6339 - loss: 0.1725 - val_accuracy: 0.6253 - val_loss: 0.1755
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.6630 - loss: 0.1608 - val_accuracy: 0.6522 - val_loss: 0.1650
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.6822 - loss: 0.1537 - val_accuracy: 0.6699 - val_loss: 0.1585
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7042 - loss: 0.1440 - val_accuracy: 0.6765 - val_loss: 0.1558
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7244 - loss: 0.1370 - val_accuracy: 0.6928 - val_loss: 0.1511
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7335 - loss: 0.1321 - val_accuracy: 0.6924 - val_loss: 0.1505
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7486 - loss: 0.1261 - val_accuracy: 0.7086 - val_loss: 0.1443
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7625 - loss: 0.1204 - val_accuracy: 0.6944 - val_loss: 0.1528
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7711 - loss: 0.1168 - val_accuracy: 0.7094 - val_loss: 0.1443
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7882 - loss: 0.1102 - val_accuracy: 0.7081 - val_loss: 0.1476
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7974 - loss: 0.1058 - val_accuracy: 0.7150 - val_loss: 0.1454
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.8105 - loss: 0.1005 - val_accuracy: 0.7118 - val_loss: 0.1481
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8207 - loss: 0.0970 - val_accuracy: 0.7136 - val_loss: 0.1474
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8308 - loss: 0.0931 - val_accuracy: 0.7163 - val_loss: 0.1496
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8413 - loss: 0.0880 - val_accuracy: 0.7118 - val_loss: 0.1530
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8500 - loss: 0.0850 - val_accuracy: 0.7092 - val_loss: 0.1563
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8602 - loss: 0.0805 - val_accuracy: 0.7085 - val_loss: 0.1556
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8644 - loss: 0.0775 - val_accuracy: 0.7113 - val_loss: 0.1591
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8761 - loss: 0.0736 - val_accuracy: 0.7130 - val_loss: 0.1637
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8830 - loss: 0.0712 - val_accuracy: 0.7110 - val_loss: 0.1687
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.8926 - loss: 0.0666 - val_accuracy: 0.7102 - val_loss: 0.1732
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8996 - loss: 0.0633 - val_accuracy: 0.7083 - val_loss: 0.1767
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9087 - loss: 0.0604 - val_accuracy: 0.7091 - val_loss: 0.1812
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9135 - loss: 0.0572 - val_accuracy: 0.7043 - val_loss: 0.1916
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9183 - loss: 0.0552 - val_accuracy: 0.7089 - val_loss: 0.1937
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9241 - loss: 0.0530 - val_accuracy: 0.7032 - val_loss: 0.1994
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9346 - loss: 0.0487 - val_accuracy: 0.7077 - val_loss: 0.2006
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9386 - loss: 0.0462 - val_accuracy: 0.7008 - val_loss: 0.2141
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9423 - loss: 0.0443 - val_accuracy: 0.7029 - val_loss: 0.2159
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9461 - loss: 0.0431 - val_accuracy: 0.7002 - val_loss: 0.2196
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9552 - loss: 0.0384 - val_accuracy: 0.6989 - val_loss: 0.2382
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9549 - loss: 0.0380 - val_accuracy: 0.6972 - val_loss: 0.2371
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9623 - loss: 0.0349 - val_accuracy: 0.6988 - val_loss: 0.2445
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9650 - loss: 0.0327 - val_accuracy: 0.6976 - val_loss: 0.2514
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9683 - loss: 0.0314 - val_accuracy: 0.6936 - val_loss: 0.2668
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9716 - loss: 0.0292 - val_accuracy: 0.7017 - val_loss: 0.2693
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9747 - loss: 0.0273 - val_accuracy: 0.6954 - val_loss: 0.2822
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9779 - loss: 0.0259 - val_accuracy: 0.6940 - val_loss: 0.2911
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9763 - loss: 0.0252 - val_accuracy: 0.6914 - val_loss: 0.3026
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9835 - loss: 0.0217 - val_accuracy: 0.6935 - val_loss: 0.3140
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9818 - loss: 0.0225 - val_accuracy: 0.6889 - val_loss: 0.3220
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9839 - loss: 0.0209 - val_accuracy: 0.6909 - val_loss: 0.3326
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9857 - loss: 0.0197 - val_accuracy: 0.6876 - val_loss: 0.3411
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9877 - loss: 0.0174 - val_accuracy: 0.6907 - val_loss: 0.3521
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9887 - loss: 0.0170 - val_accuracy: 0.6939 - val_loss: 0.3617
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9890 - loss: 0.0160 - val_accuracy: 0.6867 - val_loss: 0.3739
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.9910 - loss: 0.0150 - val_accuracy: 0.6867 - val_loss: 0.3788
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
from sklearn.metrics import accuracy_score, f1_score

accuracy = accuracy_score(y_test, y_pred_one_hot)
print(f'Accuracy: {accuracy}')

f1_macro = f1_score(y_test, y_pred_one_hot, average='macro')
f1_micro = f1_score(y_test, y_pred_one_hot, average='micro')
f1_weighted = f1_score(y_test, y_pred_one_hot, average='weighted')
f1_samples = f1_score(y_test, y_pred_one_hot, average='samples')

print(f'F1 Macro: {f1_macro}')
print(f'F1 Micro: {f1_micro}')
print(f'F1 Weighted: {f1_weighted}')
print(f'F1 Samples: {f1_samples}')
# Out:
# Accuracy: 0.6867
# F1 Macro: 0.6865610191178021
# F1 Micro: 0.6867
# F1 Weighted: 0.6865610191178022
# F1 Samples: 0.6867
